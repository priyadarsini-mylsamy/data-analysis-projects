# %%
import pandas as pd

# %%
df = pd.read_csv("/home/pri/Downloads/winemag-data_first150k.csv",index_col=0)

# %% [markdown]
# Let us create a data frame for wine from US

# %%
df_us = df.loc[df["country"] == 'US']

# %%
df_us
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 8           US  This re-named vineyard was formerly bottled as...
# 9           US  The producer sources from two blocks of the vi...
# 11          US  From 18-year-old vines, this supple well-balan...
# 12          US  A standout even in this terrific lineup of 201...
# 14          US  With its sophisticated mix of mineral, acid an...
# 15          US  First made in 2006, this succulent luscious Ch...
# 16          US  This blockbuster, powerhouse of a wine suggest...
# 19          US  This fresh and lively medium-bodied wine is be...
# 20          US  Heitz has made this stellar rosé from the rare...
# 23          US  The apogee of this ambitious winery's white wi...
# ...

# %% [markdown]
# Let's find the most expensive wine in US

# %%
expensive_US_wine = df_us[["description","price"]].loc[df_us["price"]==max(df_us["price"])]

# %%
expensive_US_wine
# Out:
#                                              description   price
# 13318  The nose on this single-vineyard wine from a s...  2013.0

# %% [markdown]
# Let us find the cheapest wine in the US

# %%
cheapest_US_wine=df_us[["description", "price","points"]].loc[df_us["price"]==min(df_us["price"])]

# %%
cheapest_US_wine
# Out:
#                                               description  price  points
# 1858    Sweet and fruity, this canned wine feels soft ...    4.0      83
# 25645   There's a lot going on in this Merlot, which i...    4.0      86
# 48655   There's a lot going on in this Merlot, which i...    4.0      86
# 80185   There's a lot going on in this Merlot, which i...    4.0      86
# 114167  Easy, simple peach and strawberry flavors are ...    4.0      83
# 118347  Light and earthy, this wine-in-a-box is clean ...    4.0      84
# 119285  Packaged in a cute yellow recyclable Tetrapak,...    4.0      84
# 119295  A good everyday Merlot, dry and rich in tannin...    4.0      84
# 126595  There's a lot going on in this Merlot, which i...    4.0      86
